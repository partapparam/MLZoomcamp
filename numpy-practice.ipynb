# %%
import numpy as np
zeros = np.zeros(19)
zeros

# %%
ones = np.ones(13)
ones

# %%
arr = np.full(10, 15)
arr

# %%
arr = np.repeat(0, 10)
arr
two = np.repeat([1,3, 2,4 ,5], [1,2,3,3,2])
two

# %%
print(two[[3, 4, 5, 6]])
# unlike python lists, we can access multiple indexes of the two array at the same time using a list of indices

# %%
array = [12, 12, 12, 12, 12]
a = np.array(array)
a

# %%
np.arange(10)

# %%
thresholds = np.linspace(0, 1, 11)
thresholds
# takes 3 arguments - the start number, the end number, and how many values we want in the array

# %%
# Think of 1D arrays as Vectors
# In Numpy, a 2D array is like a matrix
zeros = np.zeros((5,2))
zeros
print(zeros.shape)

# %%
nums = [
    [1 ,2],
    [3,4],
    [5,6]
]
array = np.array(nums)
array

# %%
array[1,1]

# %%
array[0]

# %%
#get the column
array[:,1]

# %%
array[1] = [8,8]
array[:,0] = [0, 9, 9]
array

# %%
# random arrays - it will generate different numbers every time.
arr = np.random.rand(3,2)
arr

# %%
# if we want the results to be the same, we can set the seed of the random number generator. Once seed is set, it produces the same sequence
np.random.seed(5)
arr = np.random.rand(3,2)
arr

# %%
randint = np.random.randint(low=0, high=100, size=(5,2))
randint

# %%
pred1 = np.random.rand(3).round(2)
pred2 = np.random.rand(3).round(2)
print(pred1, pred2)

# %%
pred1 >= pred2

# %%
matrix = np.random.rand(4, 3).round(2)
matrix

# %%
print(matrix.max())
# print max in each row
print(matrix.max(axis=1))
# print max in each col.
print(matrix.max(axis=0))

# %%
rng = np.arange(12)
rng

# %%
re = rng.reshape(4, 3)
re

# %%
vec = np.arange(3)
mat = np.arange(6).reshape(3, 2)
print(vec, mat)

# %%
ver = np.concatenate([vec, vec])
ver

# %%
np.hstack([vec, vec])

# %%
np.hstack([mat, mat])

# %%
np.concatenate([mat, mat])

# %%
np.column_stack([vec, mat])

# %%
np.vstack([vec, mat.T])

# %%
mat.T

# %%
mat
